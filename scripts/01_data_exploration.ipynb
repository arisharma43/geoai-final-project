# %% [markdown]
# ## Notebook for exploring necessary GeoAI data

# %%
import geopandas as gpd

# Load flood zones
floods = gpd.read_file('D:/Coding/geoai-final-project/data/small/48201C_20251130/S_FLD_HAZ_AR.shp')

print(f"✅ Loaded {len(floods)} flood zones")
print(f"Zones available: {floods['FLD_ZONE'].unique()}")
print(f"CRS: {floods.crs}")

print(floods.head())
print(floods.columns)
floods.plot(figsize=(10,10))
# Out:
# ✅ Loaded 10741 flood zones
# Zones available: ['A' 'AE' 'AO' 'AREA NOT INCLUDED' 'VE' 'X']
# CRS: EPSG:4269
#   DFIRM_ID VERSION_ID   FLD_AR_ID STUDY_TYP FLD_ZONE ZONE_SUBTY SFHA_TF  \
# 0   48201C    1.1.1.0   48201C_13        NP        A       None       T
# 1   48201C    1.1.1.0   48201C_45        NP        A       None       T
# 2   48201C    1.1.1.0   48201C_53        NP        A       None       T
# 3   48201C    1.1.1.0   48201C_79        NP        A       None       T
# 4   48201C    1.1.1.0  48201C_211        NP        A       None       T
#
#    STATIC_BFE V_DATUM   DEPTH LEN_UNIT  VELOCITY VEL_UNIT AR_REVERT AR_SUBTRV  \
# 0     -9999.0    None -9999.0     None   -9999.0     None      None      None
# 1     -9999.0    None -9999.0     None   -9999.0     None      None      None
# 2     -9999.0    None -9999.0     None   -9999.0     None      None      None
# 3     -9999.0    None -9999.0     None   -9999.0     None      None      None
# ...
